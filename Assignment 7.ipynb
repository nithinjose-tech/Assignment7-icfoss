# %% [markdown]
# # Assignment 7 - Nithin Jose

# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import seaborn as sn
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Advertising.csv')
df
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# radio         0
# newspaper     0
# sales         0
# dtype: int64

# %%
df.drop("Unnamed: 0",axis=1)
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
sn.pairplot(df)

# %%
sn.lmplot(x='TV',y='sales',data=df)

# %%
sn.lmplot(x='radio',y='sales',data=df)

# %%
sn.lmplot(x='newspaper',y='sales',data=df)

# %% [markdown]
# # 1)  yes ther is a relationship between  ads and sales

# %% [markdown]
# # 2)  There is a linear relationship between each of the ads:TV,RADIO,NEWSPAPER AND revenue

# %% [markdown]
# # TV is contrib

# %%
def gradient_descent(x,y):
    m_curr = b_curr = 0
    iterations = 80
    n = len(x)
    learning_rate = 0.001
    #%matplotlib inline
    plt.xlabel('area')
    plt.ylabel('price')
    plt.scatter(x,y,color='red',marker='+')

    for i in range(iterations):
        y_predicted = m_curr * x + b_curr
        plt.plot(x,y_predicted,color='green')
        cost = (1/n) * sum([val**2 for val in (y-y_predicted)])
        md = -(2/n)*sum(x*(y-y_predicted))
        bd = -(2/n)*sum(y-y_predicted)
        m_curr = m_curr - learning_rate * md
        b_curr = b_curr - learning_rate * bd
        print ("m {}, b {}, cost {} iteration {}".format(m_curr,b_curr,cost, i))

# %%
gradient_descent(df.TV,df.sales)
# Out:
# m 4.8210834, b 0.028045000000000007, cost 223.71625000000003 iteration 0
# m -269.5607281884622, b -1.3617744016889994, cost 650030.1877122016 iteration 1
# m 15346.241734976402, b 77.94276089641826, cost 2105407569.239718 iteration 2
# m -873390.8862665354, b -4435.28458025591, cost 6819526295654.815 iteration 3
# m 49707018.51664798, b 252424.77282159874, cost 2.2088806027201356e+16 iteration 4
# m -2828959501.4398904, b -14366168.589147465, cost 7.154680993309694e+19 iteration 5
# m 161003659311.6085, b 817617118.7570264, cost 2.317438980313807e+23 iteration 6
# m -9163149312581.44, b -46532779264.106834, cost 7.50630731474939e+26 iteration 7
# m 521499360223875.3, b 2648305051884.961, cost 2.4313326038828595e+30 iteration 8
# m -2.9679924820224508e+16, b -150722130909657.22, cost 7.875214779827034e+33 iteration 9
# m 1.6891639846998392e+18, b 8578000004107878.0, cost 2.5508236811928307e+37 iteration 10
# ...

# %%
gradient_descent(df.radio,df.sales)
# Out:
# m 0.7412639000000002, b 0.028045000000000007, cost 223.71625000000003 iteration 0
# m 0.35370226699746, b 0.0215443832608, cost 92.32078294903626 iteration 1
# m 0.555954800831779, b 0.03308923541542059, cost 56.427829727692455 iteration 2
# m 0.4500281747738891, b 0.03520059197148873, cost 46.607920811576825 iteration 3
# m 0.5051260355850171, b 0.04223627987166624, cost 43.90620467079716 iteration 4
# m 0.4760883629239402, b 0.04669430312822323, cost 43.1478412788387 iteration 5
# m 0.49101184983535134, b 0.05249447517184169, cost 42.92005408939122 iteration 6
# m 0.48296566976358946, b 0.057588686872358776, cost 42.83714274007503 iteration 7
# m 0.4869213385287294, b 0.06304708281585376, cost 42.793807636130175 iteration 8
# m 0.4846061559400676, b 0.06831051261115734, cost 42.76130104110639 iteration 9
# m 0.485567651180596, b 0.07367113636235556, cost 42.7317745444252 iteration 10
# m 0.48481721748485895, b 0.07897630241550008, cost 42.703085434014596 iteration 11
# ...

# %%
gradient_descent(df.newspaper,df.sales)
# Out:
# m 0.9085102999999999, b 0.028045000000000007, cost 223.71625000000003 iteration 0
# m -0.7384860097242201, b 0.0005166625876000044, cost 559.1700782190426 iteration 1
# m 2.245852816749244, b 0.07368803234465249, cost 1661.0974115781491 iteration 2
# m -3.1631588646115723, b -0.03565391764594959, cost 5280.443408196741 iteration 3
# m 6.639066624432084, b 0.18575670208802625, cost 17168.042713874078 iteration 4
# m -11.125974143825742, b -0.19226989460194593, cost 56212.036381362865 iteration 5
# m 21.069035996430657, b 0.5160456731681613, cost 184448.9624783269 iteration 6
# m -37.278361557958384, b -0.7444280698480599, cost 605632.7025889831 iteration 7
# m 68.46389831736815, b 1.5631119043753583, cost 1988976.0392724362 iteration 8
# m -123.17289627192122, b -2.595661217811123, cost 6532453.042314763 iteration 9
# m 224.12922567772893, b 4.9644244500090675, cost 21455127.867928207 iteration 10
# m -405.28557683890114, b -8.713548121605616, cost 70467420.03738555 iteration 11
# ...

# %% [markdown]
# # 3)TV ads contribute more to sales since cost of tv add's only 4.2220631604492623e+279

# %% [markdown]
# # 4) Priority of contribution ot ads:
#             1.TV,
#             2.Newspaper,
#             3.Radio

# %%
x=df[['TV', 'radio', 'newspaper']]

# %%
x
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y=df[['sales']]

# %%
y
# Out:
#      sales
# 0     22.1
# 1     10.4
# 2      9.3
# 3     18.5
# 4     12.9
# ..     ...
# 195    7.6
# 196    9.7
# 197   12.8
# 198   25.5
# 199   13.4
#
# [200 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import pickle

# %%
# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.3, random_state=109)

# %%
linearRegr =  LinearRegression()
linearRegr.fit(X_train, y_train)
y_pred = linearRegr.predict(X_test)

# %%
y_pred
# Out:
# array([[12.54218191],
#        [ 4.60040626],
#        [16.5247451 ],
#        [ 9.73278268],
#        [20.36174896],
#        [12.72787361],
#        [ 5.48933228],
#        [14.62435861],
#        [17.8187233 ],
#        [ 9.21236445],
#        [12.72444176],
#        [21.37561929],
#        [21.76681849],
#        [18.60824449],
#        [10.69293344],
#        [19.45145497],
#        [ 7.16796557],
#        [14.69930378],
#        [16.89992076],
#        [18.47178284],
#        [13.69614614],
#        [15.24340233],
#        [ 9.93781365],
#        [10.179446  ],
#        [ 7.79393853],
#        [14.24413441],
#        [19.40199462],
#        [21.98258389],
#        [21.17683927],
#        [23.3101159 ],
#        [ 8.24281158],
#        [18.06763255],
#        [ 6.6491614 ],
#        [17.02074868],
#        [ 3.87966943],
#        [17.35146554],
#        [ 5.49310031],
#        [13.91646556],
#        [24.10897061],
#        [ 7.52746954],
#        [15.47249126],
# ...

# %%
linearRegr.score(X_test,y_test)
# Out:
# 0.8742475510864718

# %%
linearRegr.predict([[230.1,4.9,13.8]])
# Out:
# /home/nithin/Desktop/foss/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[14.32749098]])

# %%
#Saving the Model
pickle_out = open("advertisement.pkl", "wb") 
pickle.dump(linearRegr, pickle_out) 
pickle_out.close()

# %% [markdown]
# # 5)Yes sales can be predicted for the given ad spending.

# %% [markdown]
# # Refer Advertising.py where it is deployed in streamlit
